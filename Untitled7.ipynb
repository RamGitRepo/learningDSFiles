# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
day=[1,2,3,4,5]
max_t=[15,22,30,40]
min_t=[50,53,55,89]
avg_t=[15,16,17,19]
plt.plot(x,y,color='green',marker='d',linestyle="dotted",markersize=20,alpha=0.2)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9f93fc9d7ff2> in <module>
#       4 avg_t = [15,16,17,19]
#       5
# ----> 6 plt.plot(day,max_t)
#       7 plt.plot(day,min_t)
#       8 plt.plot(day,avg_t)
#
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %%
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
day = [1,2,3,4,5]
max_t = [15,22,30,40]

# %%
pl.plot(day,max_t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ecd4c33bfd54> in <module>
# ----> 1 pl.plot(day,max_t)
#
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# C:\Program Files (x86)\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...
