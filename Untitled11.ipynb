# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_val=[4000,2000,1500,1000]
ex_labels=["Room Rent","Groceries","Food","WIFI"]
plt.pie(exp_val,labels=ex_labels,radius=1.5,autopct="%0.2f%%",explode=[0,0,0,0],shadow=True,startangle=180)
plt.savefig("C://Users//ramna//file//DataFrame//piechart.png",bbox_inches=)
